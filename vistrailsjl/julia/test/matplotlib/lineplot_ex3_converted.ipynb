# %% [markdown]
# # Workflow: lineplot_ex3.vt
#
# Converted from version 16

# %%
#| workflow: lineplot_ex3

# %%
#| module-id: mpllineplot
#| module-type: org.vistrails.vistrails.matplotlib:MplLinePlot
#| params:
#|   - x: "[1, 2, 3, 4]"
#|   - y: "[20, 21, 20.5, 20.8]"
# Out:
# Dict{String, Any} with 1 entry:
#   "value" => #compute##6

# %%
#| module-id: mplfigure
#| module-type: org.vistrails.vistrails.matplotlib:MplFigure
#| inputs:
#|   - addPlot: mpllineplot.value
# Out:
# Dict{String, Any} with 2 entries:
#   "figure" => Plot{Plots.GRBackend() n=1}
#   "self" => Plot{Plots.GRBackend() n=1}

# %%
#| module-id: mplfigureoutput
#| module-type: org.vistrails.vistrails.matplotlib:MplFigureOutput
#| inputs:
#|   - value: mplfigure.self
# Out:
# Dict{String, Any}()

# %%
#| execute
