# %% [markdown]
# # Math Workflow Test
#
# Tests the math package modules.
#
# Pipeline: `(10 + 5) / 3 * 2 = 10`
#
# Steps:
# 1. Add 10 + 5 = 15
# 2. Divide 15 / 3 = 5.0
# 3. Multiply 5.0 * 2 = 10.0

# %%
#| workflow: math_test

# %% [markdown]
# ## Define constants

# %%
#| module-id: const_10
#| module-type: basic:Float
#| params:
#|   value: 10.0

# %%
#| module-id: const_5
#| module-type: basic:Float
#| params:
#|   value: 5.0

# %%
#| module-id: const_3
#| module-type: basic:Float
#| params:
#|   value: 3.0

# %%
#| module-id: const_2
#| module-type: basic:Float
#| params:
#|   value: 2.0

# %% [markdown]
# ## Build computation: (10 + 5) / 3 * 2

# %%
#| module-id: add_step
#| module-type: org.vistrails.vistrails.math:Add
#| inputs:
#|   a: const_10.value
#|   b: const_5.value

# %%
#| module-id: divide_step
#| module-type: org.vistrails.vistrails.math:Divide
#| inputs:
#|   arg1: add_step.sum
#|   arg2: const_3.value

# %%
#| module-id: multiply_step
#| module-type: org.vistrails.vistrails.math:Multiply
#| inputs:
#|   a: divide_step.result
#|   b: const_2.value

# %% [markdown]
# ## Specify outputs

# %%
#| outputs:
#|   - name: final_result
#|     source: multiply_step.product

# %% [markdown]
# ## Execute

# %%
#| execute
