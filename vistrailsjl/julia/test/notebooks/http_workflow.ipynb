# %% [markdown]
# # HTTP Workflow Test
#
# Fetches JSON data from httpbin.org and parses it.
#
# Pipeline: HTTPFile → JSONParser
#
# Expected: Fetch JSON and extract a field

# %%
#| workflow: http_test

# %% [markdown]
# ## Fetch JSON data from httpbin.org

# %%
#| module-id: fetch_json
#| module-type: org.vistrails.vistrails.http:HTTPFile
#| params:
#|   url: "https://httpbin.org/json"

# %% [markdown]
# ## Parse and extract slideshow title

# %%
#| module-id: parse_json
#| module-type: org.vistrails.vistrails.http:JSONParser
#| inputs:
#|   json_string: fetch_json.file
#| params:
#|   field: "slideshow"

# %% [markdown]
# ## Specify workflow outputs

# %%
#| outputs:
#|   - name: json_data
#|     source: fetch_json.file
#|   - name: slideshow
#|     source: parse_json.result

# %%
#| execute

# %% [markdown]
# ## Execute the workflow
