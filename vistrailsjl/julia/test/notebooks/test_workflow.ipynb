# %% [markdown]
# # Test Workflow
#
# A simple workflow: Integer(5) -> AddOne -> Double
#
# Expected result: (5 + 1) * 2 = 12

# %%
#| workflow: test_computation

# %%
#| module-id: const1
#| module-type: basic:Integer
#| params:
#|   - value: 5

# %%
#| module-id: add
#| module-type: testpkg:AddOne
#| inputs:
#|   - value: const1.value

# %%
#| module-id: double
#| module-type: testpkg:Double
#| inputs:
#|   - value: add.result

# %%
#| execute
