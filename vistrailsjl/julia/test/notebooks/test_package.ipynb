# %% [markdown]
# # Test Package
#
# A simple test package with an AddOne module.

# %%
#| package-meta
#| identifier: test.testpkg
#| version: 1.0.0

# %%
#| module: AddOne
#| input_ports:
#|   - name: value
#|     signature: basic:Integer
#| output_ports:
#|   - name: result
#|     signature: basic:Integer

v = get_input("value")
set_output("result", v + 1)

# %%
#| module: Double
#| input_ports:
#|   - name: value
#|     signature: basic:Integer
#| output_ports:
#|   - name: result
#|     signature: basic:Integer

v = get_input("value")
set_output("result", v * 2)
